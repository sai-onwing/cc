# %%
# %ls
# Out:
# crop_clothes.py  crop_clothes.pyc  data/  demo.ipynb  __init__.py

# %%
# %load_ext autoreload
# %autoreload 2
import crop_clothes

# %%
crop_clothes.main()
# Out:
# processing ./data/clothes/input/messi.jpg
# find 1 face(s)
# Saved result in ./data/clothes/output/messi_0.jpg
# processing ./data/clothes/input/timg.jpg
# find 1 face(s)
# Saved result in ./data/clothes/output/timg_0.jpg
# processing ./data/clothes/input/dress.jpg
# find 1 face(s)
# Saved result in ./data/clothes/output/dress_0.jpg

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

img = mpimg.imread('./data/clothes/input/timg.jpg')
plt.figure()
plt.subplot(121)
plt.imshow(img)

result = mpimg.imread('./data/clothes/output/timg_0.jpg')
plt.subplot(122)
plt.imshow(result)
plt.show()
